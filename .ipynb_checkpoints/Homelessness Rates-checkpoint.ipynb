# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
rates = pd.read_csv('homelessness rates.csv')
rates.columns
# Out:
# Index(['state', 'homelessness_rate'], dtype='object')

# %%
graph = sns.barplot(x='state', y='homelessness_rate', data=rates);
graph.set_xticklabels(graph.get_xticklabels(), rotation=90)
plt.title('Homelessness Rates by State (Per 100,000 People)')
plt.ylabel('Homelessness Rates Per 100,000 People')
plt.xlabel('State')
sns.set(rc={'figure.figsize':(15,15)})
